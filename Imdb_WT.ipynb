# %%
import pandas as pd 
import numpy as np

# %%
df =pd.read_csv("IMDB_Movies_01.csv")

# %% [markdown]
# ##Checking the data for understanding

# %%
pd.set_option("display.max_columns", None)

# %%
df.head(10)
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
# 5  Color     Andrew Stanton                   462.0     132.0
# 6  Color          Sam Raimi                   392.0     156.0
# 7  Color       Nathan Greno                   324.0     100.0
# 8  Color        Joss Whedon                   635.0     141.0
# 9  Color        David Yates                   375.0     153.0
#
#    director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                      0.0                   855.0   Joel David Moore
# 1                    563.0                  1000.0      Orlando Bloom
# 2                      0.0                   161.0       Rory Kinnear
# ...

# %%
shape = df.shape
shape
# Out:
# (5043, 28)

# %%
# Display basic information about the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
#CHecking for missing values
missing_values = df.isnull().sum()
missing_values
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          20
# language                      14
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
df.drop(columns=['color','num_critic_for_reviews','duration','director_facebook_likes','actor_3_facebook_likes','actor_1_facebook_likes','num_voted_users',
                'cast_total_facebook_likes','facenumber_in_poster','plot_keywords','movie_imdb_link','num_user_for_reviews','actor_2_facebook_likes','movie_facebook_likes','aspect_ratio'],inplace=True)

# %%
#Used sort_index
df.sort_index(axis=1,inplace=True)
df
# Out:
#          actor_1_name      actor_2_name          actor_3_name       budget  \
# 0         CCH Pounder  Joel David Moore             Wes Studi  237000000.0
# 1         Johnny Depp     Orlando Bloom        Jack Davenport  300000000.0
# 2     Christoph Waltz      Rory Kinnear      Stephanie Sigman  245000000.0
# 3           Tom Hardy    Christian Bale  Joseph Gordon-Levitt  250000000.0
# 4         Doug Walker        Rob Walker                   NaN          NaN
# ...               ...               ...                   ...          ...
# 5038      Eric Mabius     Daphne Zuniga          Crystal Lowe          NaN
# 5039      Natalie Zea     Valorie Curry         Sam Underwood          NaN
# 5040      Eva Boehnke     Maxwell Moody        David Chandler       1400.0
# 5041        Alan Ruck     Daniel Henney           Eliza Coupe          NaN
# 5042      John August  Brian Herzlinger              Jon Gunn       1100.0
#
#      content_rating country      director_name  \
# ...

# %%
##df.fillna(0)
df.dropna()
# Out:
#          actor_1_name        actor_2_name          actor_3_name       budget  \
# 0         CCH Pounder    Joel David Moore             Wes Studi  237000000.0
# 1         Johnny Depp       Orlando Bloom        Jack Davenport  300000000.0
# 2     Christoph Waltz        Rory Kinnear      Stephanie Sigman  245000000.0
# 3           Tom Hardy      Christian Bale  Joseph Gordon-Levitt  250000000.0
# 5        Daryl Sabara     Samantha Morton          Polly Walker  263700000.0
# ...               ...                 ...                   ...          ...
# 5033    Shane Carruth      David Sullivan          Casey Gooden       7000.0
# 5034      Ian Gamazon     Edgar Tancangco             Quynn Ton       7000.0
# 5035  Carlos Gallardo     Peter Marquardt        Consuelo Gómez       7000.0
# 5037      Kerry Bishé  Caitlin FitzGerald       Daniella Pineda       9000.0
# 5042      John August    Brian Herzlinger              Jon Gunn       1100.0
#
# ...

# %%
df
# Out:
#                                                                          actor_1_name  \
# movie_title                                        director_name
# Avatar                                             James Cameron          CCH Pounder
# Pirates of the Caribbean: At World's End           Gore Verbinski         Johnny Depp
# Spectre                                            Sam Mendes         Christoph Waltz
# The Dark Knight Rises                              Christopher Nolan        Tom Hardy
# Star Wars: Episode VII - The Force Awakens     ... Doug Walker            Doug Walker
# ...                                                                               ...
# Signed Sealed Delivered                            Scott Smith            Eric Mabius
# The Following                                      NaN                    Natalie Zea
# A Plague So Pleasant                               Benjamin Roberds       Eva Boehnke
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   actor_1_name    5036 non-null   object
#  1   actor_2_name    5030 non-null   object
#  2   actor_3_name    5020 non-null   object
#  3   budget          4551 non-null   float64
#  4   content_rating  4740 non-null   object
#  5   country         5038 non-null   object
#  6   director_name   4939 non-null   object
#  7   genres          5043 non-null   object
#  8   gross           4159 non-null   float64
#  9   imdb_score      5043 non-null   float64
#  10  language        5029 non-null   object
#  11  movie_title     5043 non-null   object
#  12  title_year      4935 non-null   float64
# dtypes: float64(4), object(9)
# memory usage: 512.3+ KB

# %%
# Calculate profit (assuming 'gross' and 'budget' columns are available)
df['profit'] = df['gross'] - df['budget']

# Calculate ROI (Return on Investment)
df['roi'] = (df['gross'] - df['budget']) / df['budget']

# Display the first few rows to check the new columns
df[['gross', 'budget', 'profit', 'roi']].head()
# Out:
#          gross       budget       profit       roi
# 0  760505847.0  237000000.0  523505847.0  2.208885
# 1  309404152.0  300000000.0    9404152.0  0.031347
# 2  200074175.0  245000000.0  -44925825.0 -0.183371
# 3  448130642.0  250000000.0  198130642.0  0.792523
# 4          NaN          NaN          NaN       NaN

# %% [markdown]
# ##Question 1: Which movie made the highest profit? Who were its producer and director? Identify the actors in that film.

# %%
# Find the movie with the highest profit
highest_profit_movie = df.loc[df['profit'].idxmax()]

# Extract relevant details
highest_profit_details = {
    'movie_title': highest_profit_movie['movie_title'],
    'profit': highest_profit_movie['profit'],
    'director': highest_profit_movie['director_name'],
    'producer': highest_profit_movie['producer_name'] if 'producer_name' in df.columns else 'N/A',
    'actors': [highest_profit_movie['actor_1_name'], highest_profit_movie['actor_2_name'], highest_profit_movie['actor_3_name']]
}

highest_profit_details
# Out:
# {'movie_title': 'Avatar\xa0',
#  'profit': 523505847.0,
#  'director': 'James Cameron',
#  'producer': 'N/A',
#  'actors': ['CCH Pounder', 'Joel David Moore', 'Wes Studi']}

# %% [markdown]
# ##Question 2: Which language has the highest average ROI?

# %%
# Group by language and calculate the average ROI
language_roi = df.groupby('language')['roi'].mean()

# Find the language with the highest average ROI
highest_avg_roi_language = language_roi.idxmax()
highest_avg_roi_value = language_roi.max()

highest_avg_roi_language, highest_avg_roi_value
# Out:
# ('Persian', 27.90536874074074)

# %% [markdown]
# ##Question 3: Find out the unique genres of movies in this dataset.

# %%
# Split the genres column and find unique genres
unique_genres = set(genre for sublist in df['genres'].str.split('|').dropna() for genre in sublist)
unique_genres
# Out:
# {'Action',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Film-Noir',
#  'Game-Show',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Reality-TV',
#  'Romance',
#  'Sci-Fi',
#  'Short',
#  'Sport',
#  'Thriller',
#  'War',
#  'Western'}

# %% [markdown]
# ##Question 4: Make a table of all the producers and directors of each movie. Find the top 3 producers who have produced movies with the highest average ROI.

# %% [markdown]
# ##In the dataset i have taken there is no column of producer_name so couldn't produce the result

# %%
# Create a table of producers and directors
producers_directors = df[['movie_title', 'producer_name', 'director_name']]

# Group by producer and calculate the average ROI
producer_roi = df.groupby('producer_name')['roi'].mean()

# Find the top 3 producers with the highest average ROI
top_3_producers = producer_roi.nlargest(3)

top_3_producers
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[101], line 2
#       1 # Create a table of producers and directors
# ----> 2 producers_directors = df[['movie_title', 'producer_name', 'director_name']]
#       4 # Group by producer and calculate the average ROI
#       5 producer_roi = df.groupby('producer_name')['roi'].mean()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6115, in Index._get_indexer_strict(self, key, axis_name)
#    6112 else:
# ...

# %% [markdown]
# ##Question 5: Which actor has acted in the most number of movies? Deep dive into the movies, genres, and profits corresponding to this actor.

# %%
# Count the number of movies each actor has appeared in
actors = pd.concat([df['actor_1_name'], df['actor_2_name']])
actor_counts = actors.value_counts()

# Find the actor with the most movie appearances
most_frequent_actor = actor_counts.idxmax()

# Get all movies, genres, and profits corresponding to this actor
movies_with_actor = df[(df['actor_1_name'] == most_frequent_actor) | 
                       (df['actor_2_name'] == most_frequent_actor)]

most_frequent_actor_details = {
    'actor': most_frequent_actor,
    'movie_count': actor_counts.max(),
    'movies': movies_with_actor[['movie_title', 'genres', 'profit']]
}

most_frequent_actor_details
# Out:
# {'actor': 'Robert De Niro',
#  'movie_count': 54,
#  'movies':                                 movie_title  \
#  293                         Little Fockers
#  518   The Adventures of Rocky & Bullwinkle
#  541                             Shark Tale
#  619                           Killer Elite
#  632                              The Score
#  710                       Meet the Fockers
#  761                                    Joy
#  783                           Analyze That
#  784                         Righteous Kill
#  838                       Meet the Parents
#  868                                  Ronin
#  879                                The Fan
#  920                                 Casino
#  1140                              Sleepers
#  1168                            15 Minutes
#  1209                            The Intern
#  1281                          Mean Streets
#  1285                       City by the Sea
#  1337                          Grudge Match
# ...
